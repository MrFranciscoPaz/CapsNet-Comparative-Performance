# %%
import numpy as np
import os
import pandas as pd
from keras.preprocessing.image import ImageDataGenerator
from keras import callbacks
from keras.utils.vis_utils import plot_model
# Out:
# Using TensorFlow backend.

# %%
import keras.backend as K
import tensorflow as tf
from keras import initializers, layers

class Length(layers.Layer):
    """
    Compute the length of vectors. This is used to compute a Tensor that has the same shape with y_true in margin_loss
    inputs: shape=[dim_1, ..., dim_{n-1}, dim_n]
    output: shape=[dim_1, ..., dim_{n-1}]
    """
    def call(self, inputs, **kwargs):
        return K.sqrt(K.sum(K.square(inputs), -1))

    def compute_output_shape(self, input_shape):
        return input_shape[:-1]

class Mask(layers.Layer):
    """
    Mask a Tensor with shape=[None, d1, d2] by the max value in axis=1.
    Output shape: [None, d2]
    """
    def call(self, inputs, **kwargs):
        # use true label to select target capsule, shape=[batch_size, num_capsule]
        if type(inputs) is list:  # true label is provided with shape = [batch_size, n_classes], i.e. one-hot code.
            assert len(inputs) == 2
            inputs, mask = inputs
        else:  # if no true label, mask by the max length of vectors of capsules
            x = inputs
            # Enlarge the range of values in x to make max(new_x)=1 and others < 0
            x = (x - K.max(x, 1, True)) / K.epsilon() + 1
            mask = K.clip(x, 0, 1)  # the max value in x clipped to 1 and other to 0

        # masked inputs, shape = [batch_size, dim_vector]
        inputs_masked = K.batch_dot(inputs, mask, [1, 1])
        return inputs_masked

    def compute_output_shape(self, input_shape):
        if type(input_shape[0]) is tuple:  # true label provided
            return tuple([None, input_shape[0][-1]])
        else:
            return tuple([None, input_shape[-1]])


def squash(vectors, axis=-1):
    """
    The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
    :param vectors: some vectors to be squashed, N-dim tensor
    :param axis: the axis to squash
    :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / K.sqrt(s_squared_norm)
    return scale * vectors


class CapsuleLayer(layers.Layer):
    """
    The capsule layer. It is similar to Dense layer. Dense layer has `in_num` inputs, each is a scalar, the output of the 
    neuron from the former layer, and it has `out_num` output neurons. CapsuleLayer just expand the output of the neuron
    from scalar to vector. So its input shape = [None, input_num_capsule, input_dim_vector] and output shape = \
    [None, num_capsule, dim_vector]. For Dense Layer, input_dim_vector = dim_vector = 1.
    
    :param num_capsule: number of capsules in this layer
    :param dim_vector: dimension of the output vectors of the capsules in this layer
    :param num_routings: number of iterations for the routing algorithm
    """
    def __init__(self, num_capsule, dim_vector, num_routing=3,
                 kernel_initializer='glorot_uniform',
                 bias_initializer='zeros',
                 **kwargs):
        super(CapsuleLayer, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_vector = dim_vector
        self.num_routing = num_routing
        self.kernel_initializer = initializers.get(kernel_initializer)
        self.bias_initializer = initializers.get(bias_initializer)

    def build(self, input_shape):
        assert len(input_shape) >= 3, "The input Tensor should have shape=[None, input_num_capsule, input_dim_vector]"
        self.input_num_capsule = input_shape[1]
        self.input_dim_vector = input_shape[2]

        # Transform matrix
        self.W = self.add_weight(shape=[self.input_num_capsule, self.num_capsule, self.input_dim_vector, self.dim_vector],
                                 initializer=self.kernel_initializer,
                                 name='W')

        # Coupling coefficient. The redundant dimensions are just to facilitate subsequent matrix calculation.
        self.bias = self.add_weight(shape=[1, self.input_num_capsule, self.num_capsule, 1, 1],
                                    initializer=self.bias_initializer,
                                    name='bias',
                                    trainable=False)
        self.built = True

    def call(self, inputs, training=None):
        # inputs.shape=[None, input_num_capsule, input_dim_vector]
        # Expand dims to [None, input_num_capsule, 1, 1, input_dim_vector]
        inputs_expand = K.expand_dims(K.expand_dims(inputs, 2), 2)

        # Replicate num_capsule dimension to prepare being multiplied by W
        # Now it has shape = [None, input_num_capsule, num_capsule, 1, input_dim_vector]
        inputs_tiled = K.tile(inputs_expand, [1, 1, self.num_capsule, 1, 1])

        """  
        # Compute `inputs * W` by expanding the first dim of W. More time-consuming and need batch_size.
        # Now W has shape  = [batch_size, input_num_capsule, num_capsule, input_dim_vector, dim_vector]
        w_tiled = K.tile(K.expand_dims(self.W, 0), [self.batch_size, 1, 1, 1, 1])
        
        # Transformed vectors, inputs_hat.shape = [None, input_num_capsule, num_capsule, 1, dim_vector]
        inputs_hat = K.batch_dot(inputs_tiled, w_tiled, [4, 3])
        """
        # Compute `inputs * W` by scanning inputs_tiled on dimension 0. This is faster but requires Tensorflow.
        # inputs_hat.shape = [None, input_num_capsule, num_capsule, 1, dim_vector]
        inputs_hat = tf.scan(lambda ac, x: K.batch_dot(x, self.W, [3, 2]),
                             elems=inputs_tiled,
                             initializer=K.zeros([self.input_num_capsule, self.num_capsule, 1, self.dim_vector]))
        """
        # Routing algorithm V1. Use tf.while_loop in a dynamic way.
        def body(i, b, outputs):
            c = tf.nn.softmax(self.bias, dim=2)  # dim=2 is the num_capsule dimension
            outputs = squash(K.sum(c * inputs_hat, 1, keepdims=True))
            b = b + K.sum(inputs_hat * outputs, -1, keepdims=True)
            return [i-1, b, outputs]

        cond = lambda i, b, inputs_hat: i > 0
        loop_vars = [K.constant(self.num_routing), self.bias, K.sum(inputs_hat, 1, keepdims=True)]
        _, _, outputs = tf.while_loop(cond, body, loop_vars)
        """
        # Routing algorithm V2. Use iteration. V2 and V1 both work without much difference on performance
        assert self.num_routing > 0, 'The num_routing should be > 0.'
        for i in range(self.num_routing):
            c = tf.nn.softmax(self.bias, dim=2)  # dim=2 is the num_capsule dimension
            # outputs.shape=[None, 1, num_capsule, 1, dim_vector]
            outputs = squash(K.sum(c * inputs_hat, 1, keepdims=True))

            # last iteration needs not compute bias which will not be passed to the graph any more anyway.
            if i != self.num_routing - 1:
                # self.bias = K.update_add(self.bias, K.sum(inputs_hat * outputs, [0, -1], keepdims=True))
                self.bias += K.sum(inputs_hat * outputs, -1, keepdims=True)
            # tf.summary.histogram('BigBee', self.bias)  # for debugging
        return K.reshape(outputs, [-1, self.num_capsule, self.dim_vector])

    def compute_output_shape(self, input_shape):
        return tuple([None, self.num_capsule, self.dim_vector])


def PrimaryCap(inputs, dim_vector, n_channels, kernel_size, strides, padding):
    """
    Apply Conv2D `n_channels` times and concatenate all capsules
    :param inputs: 4D tensor, shape=[None, width, height, channels]
    :param dim_vector: the dim of the output vector of capsule
    :param n_channels: the number of types of capsules
    :return: output tensor, shape=[None, num_capsule, dim_vector]
    """
    output = layers.Conv2D(filters=dim_vector*n_channels, kernel_size=kernel_size, strides=strides, padding=padding)(inputs)
    outputs = layers.Reshape(target_shape=[-1, dim_vector])(output)
    return layers.Lambda(squash)(outputs)

# %%
from keras import layers, models
from keras import backend as K
from keras.utils import to_categorical
def CapsNet(input_shape, n_class, num_routing):
    """
    A Capsule Network on MNIST.
    :param input_shape: data shape, 4d, [None, width, height, channels]
    :param n_class: number of classes
    :param num_routing: number of routing iterations
    :return: A Keras Model with 2 inputs and 2 outputs
    """
    x = layers.Input(shape=input_shape)

    # Layer 1: Just a conventional Conv2D layer
    conv1 = layers.Conv2D(filters=256, kernel_size=9, strides=1, padding='valid', activation='relu', name='conv1')(x)

    # Layer 2: Conv2D layer with `squash` activation, then reshape to [None, num_capsule, dim_vector]
    primarycaps = PrimaryCap(conv1, dim_vector=8, n_channels=32, kernel_size=9, strides=2, padding='valid')

    # Layer 3: Capsule layer. Routing algorithm works here.
    digitcaps = CapsuleLayer(num_capsule=n_class, dim_vector=16, num_routing=num_routing, name='digitcaps')(primarycaps)

    # Layer 4: This is an auxiliary layer to replace each capsule with its length. Just to match the true label's shape.
    # If using tensorflow, this will not be necessary. :)
    out_caps = Length(name='out_caps')(digitcaps)

    # Decoder network.
    y = layers.Input(shape=(n_class,))
    masked = Mask()([digitcaps, y])  # The true label is used to mask the output of capsule layer.
    x_recon = layers.Dense(512, activation='relu')(masked)
    x_recon = layers.Dense(1024, activation='relu')(x_recon)
    x_recon = layers.Dense(784, activation='sigmoid')(x_recon)
    x_recon = layers.Reshape(target_shape=[28, 28, 1], name='out_recon')(x_recon)

    # two-input-two-output keras Model
    return models.Model([x, y], [out_caps, x_recon])

# %%
def margin_loss(y_true, y_pred):
    """
    Margin loss for Eq.(4). When y_true[i, :] contains not just one `1`, this loss should work too. Not test it.
    :param y_true: [None, n_classes]
    :param y_pred: [None, num_capsule]
    :return: a scalar loss value.
    """
    L = y_true * K.square(K.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * K.square(K.maximum(0., y_pred - 0.1))

    return K.mean(K.sum(L, 1))

# %%
# define model
model = CapsNet(input_shape=[28, 28, 1],
                n_class=10,
                num_routing=3)
model.summary()
try:
    plot_model(model, to_file='model.png', show_shapes=True)
except Exception as e:
    print('No fancy plot {}'.format(e))
# Out:
# WARNING:tensorflow:From <ipython-input-2-8daadbc5443a>:132: calling softmax (from tensorflow.python.ops.nn_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 20, 20, 256)  20992       input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 6, 6, 256)    5308672     conv1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1152, 8)      0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1152, 8)      0           reshape_1[0][0]
# __________________________________________________________________________________________________
# digitcaps (CapsuleLayer)        (None, 10, 16)       1486080     lambda_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 10)           0
# __________________________________________________________________________________________________
# mask_1 (Mask)                   (None, 16)           0           digitcaps[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          8704        mask_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1024)         525312      dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 784)          803600      dense_2[0][0]
# __________________________________________________________________________________________________
# out_caps (Length)               (None, 10)           0           digitcaps[0][0]
# __________________________________________________________________________________________________
# out_recon (Reshape)             (None, 28, 28, 1)    0           dense_3[0][0]
# ==================================================================================================
# Total params: 8,153,360
# Trainable params: 8,141,840
# Non-trainable params: 11,520
# __________________________________________________________________________________________________

# %%
(x_train,y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# %%
x_train = x_train / 255.
x_test = x_test/ 255.
y_train = to_categorical(y_train.astype('float32'))
y_test = to_categorical(y_test.astype('float32'))
x_train = x_train[..., tf.newaxis]
x_test = x_test[..., tf.newaxis]
# Out:
# Training (42000, 28, 28, 1) 1.0
# Testing (18000, 28, 28, 1) 1.0

# %%
def train(model, data, epoch_size_frac=1.0):
    """
    Training a CapsuleNet
    :param model: the CapsuleNet model
    :param data: a tuple containing training and testing data, like `((x_train, y_train), (x_test, y_test))`
    :param args: arguments
    :return: The trained model
    """
    # unpacking the data
    (x_train, y_train), (x_test, y_test) = data

    # callbacks
    log = callbacks.CSVLogger('log.csv')
    checkpoint = callbacks.ModelCheckpoint('weights-{epoch:02d}.h5',
                                           save_best_only=True, save_weights_only=True, verbose=1)
    lr_decay = callbacks.LearningRateScheduler(schedule=lambda epoch: 0.001 * np.exp(-epoch / 10.))

    # compile the model
    model.compile(optimizer='adam',
                  loss=[margin_loss, 'mse'],
                  loss_weights=[1., 0.0005],
                  metrics={'out_caps': 'accuracy'})

    """
    # Training without data augmentation:
    model.fit([x_train, y_train], [y_train, x_train], batch_size=args.batch_size, epochs=args.epochs,
              validation_data=[[x_test, y_test], [y_test, x_test]], callbacks=[log, tb, checkpoint])
    """

    # -----------------------------------Begin: Training with data augmentation -----------------------------------#
    def train_generator(x, y, batch_size, shift_fraction=0.0):
        train_datagen = ImageDataGenerator(width_shift_range=shift_fraction,
                                           height_shift_range=shift_fraction)  # shift up to 2 pixel for MNIST
        generator = train_datagen.flow(x, y, batch_size=batch_size)
        while 1:
            x_batch, y_batch = generator.next()
            yield ([x_batch, y_batch], [y_batch, x_batch])

    # Training with data augmentation. If shift_fraction=0., also no augmentation.
    model.fit_generator(generator=train_generator(x_train, y_train, 64, 0.1),
                        steps_per_epoch=int(epoch_size_frac*y_train.shape[0] / 64),
                        epochs=50,
                        validation_data=[[x_test, y_test], [y_test, x_test]],
                        callbacks=[log, checkpoint, lr_decay])
    # -----------------------------------End: Training with data augmentation -----------------------------------#

    model.save_weights('trained_model.h5')
    print('Trained model saved to \'trained_model.h5\'')

    return model

# %%
train(model=model, data=((x_train, y_train), (x_test[:60], y_test[:60])), 
      epoch_size_frac = 0.6) # do 10% of an epoch (takes too long)
# Out:
# Epoch 1/50
# 393/393 [==============================] - 398s 1s/step - loss: 0.2332 - out_caps_loss: 0.2331 - out_recon_loss: 0.1267 - out_caps_acc: 0.6727 - val_loss: 0.1288 - val_out_caps_loss: 0.1288 - val_out_recon_loss: 0.0923 - val_out_caps_acc: 0.8500
#
# Epoch 00001: val_loss improved from inf to 0.12884, saving model to weights-01.h5
# Epoch 2/50
# 393/393 [==============================] - 373s 950ms/step - loss: 0.1529 - out_caps_loss: 0.1529 - out_recon_loss: 0.0788 - out_caps_acc: 0.7875 - val_loss: 0.1392 - val_out_caps_loss: 0.1391 - val_out_recon_loss: 0.0859 - val_out_caps_acc: 0.8167
#
# Epoch 00002: val_loss did not improve from 0.12884
# Epoch 3/50
# 393/393 [==============================] - 376s 957ms/step - loss: 0.1370 - out_caps_loss: 0.1370 - out_recon_loss: 0.0716 - out_caps_acc: 0.8124 - val_loss: 0.1158 - val_out_caps_loss: 0.1158 - val_out_recon_loss: 0.0754 - val_out_caps_acc: 0.8000
#
# Epoch 00003: val_loss improved from 0.12884 to 0.11584, saving model to weights-03.h5
# Epoch 4/50
# 393/393 [==============================] - 375s 955ms/step - loss: 0.1227 - out_caps_loss: 0.1226 - out_recon_loss: 0.0660 - out_caps_acc: 0.8355 - val_loss: 0.1178 - val_out_caps_loss: 0.1177 - val_out_recon_loss: 0.0696 - val_out_caps_acc: 0.8333
#
# Epoch 00004: val_loss did not improve from 0.11584
# Epoch 5/50
# 393/393 [==============================] - 376s 956ms/step - loss: 0.1180 - out_caps_loss: 0.1179 - out_recon_loss: 0.0631 - out_caps_acc: 0.8399 - val_loss: 0.1064 - val_out_caps_loss: 0.1064 - val_out_recon_loss: 0.0672 - val_out_caps_acc: 0.8500
#
# Epoch 00005: val_loss improved from 0.11584 to 0.10640, saving model to weights-05.h5
# Epoch 6/50
# 393/393 [==============================] - 375s 955ms/step - loss: 0.1128 - out_caps_loss: 0.1127 - out_recon_loss: 0.0612 - out_caps_acc: 0.8463 - val_loss: 0.1172 - val_out_caps_loss: 0.1172 - val_out_recon_loss: 0.0655 - val_out_caps_acc: 0.8333
#
# Epoch 00006: val_loss did not improve from 0.10640
# Epoch 7/50
# 393/393 [==============================] - 375s 954ms/step - loss: 0.1068 - out_caps_loss: 0.1068 - out_recon_loss: 0.0598 - out_caps_acc: 0.8539 - val_loss: 0.0976 - val_out_caps_loss: 0.0975 - val_out_recon_loss: 0.0638 - val_out_caps_acc: 0.8500
#
# Epoch 00007: val_loss improved from 0.10640 to 0.09755, saving model to weights-07.h5
# Epoch 8/50
# 393/393 [==============================] - 376s 956ms/step - loss: 0.1029 - out_caps_loss: 0.1029 - out_recon_loss: 0.0585 - out_caps_acc: 0.8617 - val_loss: 0.1016 - val_out_caps_loss: 0.1016 - val_out_recon_loss: 0.0621 - val_out_caps_acc: 0.8667
#
# Epoch 00008: val_loss did not improve from 0.09755
# Epoch 9/50
# 393/393 [==============================] - 375s 955ms/step - loss: 0.0999 - out_caps_loss: 0.0998 - out_recon_loss: 0.0579 - out_caps_acc: 0.8623 - val_loss: 0.0918 - val_out_caps_loss: 0.0918 - val_out_recon_loss: 0.0619 - val_out_caps_acc: 0.8500
#
# Epoch 00009: val_loss improved from 0.09755 to 0.09182, saving model to weights-09.h5
# Epoch 10/50
# 393/393 [==============================] - 376s 956ms/step - loss: 0.0989 - out_caps_loss: 0.0989 - out_recon_loss: 0.0572 - out_caps_acc: 0.8665 - val_loss: 0.0876 - val_out_caps_loss: 0.0875 - val_out_recon_loss: 0.0622 - val_out_caps_acc: 0.8667
#
# Epoch 00010: val_loss improved from 0.09182 to 0.08755, saving model to weights-10.h5
# Epoch 11/50
# 393/393 [==============================] - 375s 954ms/step - loss: 0.0946 - out_caps_loss: 0.0946 - out_recon_loss: 0.0567 - out_caps_acc: 0.8718 - val_loss: 0.0885 - val_out_caps_loss: 0.0884 - val_out_recon_loss: 0.0611 - val_out_caps_acc: 0.8500
#
# Epoch 00011: val_loss did not improve from 0.08755
# Epoch 12/50
# 393/393 [==============================] - 375s 954ms/step - loss: 0.0913 - out_caps_loss: 0.0913 - out_recon_loss: 0.0562 - out_caps_acc: 0.8751 - val_loss: 0.0897 - val_out_caps_loss: 0.0897 - val_out_recon_loss: 0.0608 - val_out_caps_acc: 0.8833
#
# Epoch 00012: val_loss did not improve from 0.08755
# Epoch 13/50
# 393/393 [==============================] - 376s 956ms/step - loss: 0.0914 - out_caps_loss: 0.0913 - out_recon_loss: 0.0558 - out_caps_acc: 0.8738 - val_loss: 0.0913 - val_out_caps_loss: 0.0912 - val_out_recon_loss: 0.0610 - val_out_caps_acc: 0.8833
#
# Epoch 00013: val_loss did not improve from 0.08755
# Epoch 14/50
# 393/393 [==============================] - 375s 954ms/step - loss: 0.0871 - out_caps_loss: 0.0871 - out_recon_loss: 0.0551 - out_caps_acc: 0.8822 - val_loss: 0.0865 - val_out_caps_loss: 0.0864 - val_out_recon_loss: 0.0606 - val_out_caps_acc: 0.8500
#
# Epoch 00014: val_loss improved from 0.08755 to 0.08647, saving model to weights-14.h5
# Epoch 15/50
# 393/393 [==============================] - 376s 956ms/step - loss: 0.0865 - out_caps_loss: 0.0865 - out_recon_loss: 0.0550 - out_caps_acc: 0.8817 - val_loss: 0.0870 - val_out_caps_loss: 0.0869 - val_out_recon_loss: 0.0603 - val_out_caps_acc: 0.8833
#
# Epoch 00015: val_loss did not improve from 0.08647
# Epoch 16/50
# 393/393 [==============================] - 375s 954ms/step - loss: 0.0850 - out_caps_loss: 0.0849 - out_recon_loss: 0.0546 - out_caps_acc: 0.8826 - val_loss: 0.0826 - val_out_caps_loss: 0.0826 - val_out_recon_loss: 0.0600 - val_out_caps_acc: 0.9000
#
# Epoch 00016: val_loss improved from 0.08647 to 0.08261, saving model to weights-16.h5
# Epoch 17/50
# 393/393 [==============================] - 375s 954ms/step - loss: 0.0821 - out_caps_loss: 0.0820 - out_recon_loss: 0.0543 - out_caps_acc: 0.8875 - val_loss: 0.0897 - val_out_caps_loss: 0.0897 - val_out_recon_loss: 0.0602 - val_out_caps_acc: 0.8833
#
# Epoch 00017: val_loss did not improve from 0.08261
# Epoch 18/50
# 393/393 [==============================] - 376s 956ms/step - loss: 0.0814 - out_caps_loss: 0.0814 - out_recon_loss: 0.0538 - out_caps_acc: 0.8871 - val_loss: 0.0840 - val_out_caps_loss: 0.0840 - val_out_recon_loss: 0.0604 - val_out_caps_acc: 0.8833
#
# Epoch 00018: val_loss did not improve from 0.08261
# Epoch 19/50
# 393/393 [==============================] - 375s 955ms/step - loss: 0.0803 - out_caps_loss: 0.0803 - out_recon_loss: 0.0539 - out_caps_acc: 0.8926 - val_loss: 0.0767 - val_out_caps_loss: 0.0767 - val_out_recon_loss: 0.0601 - val_out_caps_acc: 0.9000
#
# Epoch 00019: val_loss improved from 0.08261 to 0.07673, saving model to weights-19.h5
# Epoch 20/50
# 393/393 [==============================] - 376s 956ms/step - loss: 0.0798 - out_caps_loss: 0.0798 - out_recon_loss: 0.0538 - out_caps_acc: 0.8910 - val_loss: 0.0772 - val_out_caps_loss: 0.0772 - val_out_recon_loss: 0.0597 - val_out_caps_acc: 0.8833
#
# Epoch 00020: val_loss did not improve from 0.07673
# Epoch 21/50
# 393/393 [==============================] - 375s 954ms/step - loss: 0.0784 - out_caps_loss: 0.0784 - out_recon_loss: 0.0536 - out_caps_acc: 0.8910 - val_loss: 0.0867 - val_out_caps_loss: 0.0867 - val_out_recon_loss: 0.0599 - val_out_caps_acc: 0.9000
#
# Epoch 00021: val_loss did not improve from 0.07673
# Epoch 22/50
# 393/393 [==============================] - 375s 955ms/step - loss: 0.0762 - out_caps_loss: 0.0762 - out_recon_loss: 0.0533 - out_caps_acc: 0.8976 - val_loss: 0.0799 - val_out_caps_loss: 0.0798 - val_out_recon_loss: 0.0596 - val_out_caps_acc: 0.9000
#
# Epoch 00022: val_loss did not improve from 0.07673
# Epoch 23/50
# 393/393 [==============================] - 376s 956ms/step - loss: 0.0774 - out_caps_loss: 0.0774 - out_recon_loss: 0.0533 - out_caps_acc: 0.8927 - val_loss: 0.0818 - val_out_caps_loss: 0.0818 - val_out_recon_loss: 0.0590 - val_out_caps_acc: 0.8833
#
# Epoch 00023: val_loss did not improve from 0.07673
# Epoch 24/50
# 393/393 [==============================] - 375s 954ms/step - loss: 0.0748 - out_caps_loss: 0.0747 - out_recon_loss: 0.0530 - out_caps_acc: 0.8981 - val_loss: 0.0803 - val_out_caps_loss: 0.0803 - val_out_recon_loss: 0.0590 - val_out_caps_acc: 0.8833
#
# Epoch 00024: val_loss did not improve from 0.07673
# Epoch 25/50
# 393/393 [==============================] - 376s 956ms/step - loss: 0.0745 - out_caps_loss: 0.0745 - out_recon_loss: 0.0532 - out_caps_acc: 0.8994 - val_loss: 0.0826 - val_out_caps_loss: 0.0825 - val_out_recon_loss: 0.0593 - val_out_caps_acc: 0.8833
#
# Epoch 00025: val_loss did not improve from 0.07673
# Epoch 26/50
# 393/393 [==============================] - 375s 955ms/step - loss: 0.0728 - out_caps_loss: 0.0728 - out_recon_loss: 0.0529 - out_caps_acc: 0.9023 - val_loss: 0.0798 - val_out_caps_loss: 0.0797 - val_out_recon_loss: 0.0590 - val_out_caps_acc: 0.9000
#
# Epoch 00026: val_loss did not improve from 0.07673
# Epoch 27/50
# 393/393 [==============================] - 375s 954ms/step - loss: 0.0733 - out_caps_loss: 0.0733 - out_recon_loss: 0.0528 - out_caps_acc: 0.9002 - val_loss: 0.0804 - val_out_caps_loss: 0.0804 - val_out_recon_loss: 0.0592 - val_out_caps_acc: 0.9000
#
# Epoch 00027: val_loss did not improve from 0.07673
# Epoch 28/50
# 393/393 [==============================] - 376s 956ms/step - loss: 0.0725 - out_caps_loss: 0.0725 - out_recon_loss: 0.0530 - out_caps_acc: 0.9011 - val_loss: 0.0849 - val_out_caps_loss: 0.0849 - val_out_recon_loss: 0.0590 - val_out_caps_acc: 0.8833
#
# Epoch 00028: val_loss did not improve from 0.07673
# Epoch 29/50
# 393/393 [==============================] - 375s 955ms/step - loss: 0.0707 - out_caps_loss: 0.0707 - out_recon_loss: 0.0524 - out_caps_acc: 0.9033 - val_loss: 0.0795 - val_out_caps_loss: 0.0795 - val_out_recon_loss: 0.0584 - val_out_caps_acc: 0.8833
#
# Epoch 00029: val_loss did not improve from 0.07673
# Epoch 30/50
# 393/393 [==============================] - 376s 957ms/step - loss: 0.0709 - out_caps_loss: 0.0709 - out_recon_loss: 0.0529 - out_caps_acc: 0.9026 - val_loss: 0.0799 - val_out_caps_loss: 0.0799 - val_out_recon_loss: 0.0590 - val_out_caps_acc: 0.8833
#
# Epoch 00030: val_loss did not improve from 0.07673
# Epoch 31/50
# 393/393 [==============================] - 375s 955ms/step - loss: 0.0712 - out_caps_loss: 0.0712 - out_recon_loss: 0.0528 - out_caps_acc: 0.9011 - val_loss: 0.0805 - val_out_caps_loss: 0.0804 - val_out_recon_loss: 0.0586 - val_out_caps_acc: 0.9000
#
# Epoch 00031: val_loss did not improve from 0.07673
# Epoch 32/50
# 393/393 [==============================] - 375s 955ms/step - loss: 0.0703 - out_caps_loss: 0.0703 - out_recon_loss: 0.0524 - out_caps_acc: 0.9059 - val_loss: 0.0765 - val_out_caps_loss: 0.0765 - val_out_recon_loss: 0.0587 - val_out_caps_acc: 0.9000
#
# Epoch 00032: val_loss improved from 0.07673 to 0.07649, saving model to weights-32.h5
# Epoch 33/50
# 393/393 [==============================] - 376s 957ms/step - loss: 0.0696 - out_caps_loss: 0.0696 - out_recon_loss: 0.0525 - out_caps_acc: 0.9061 - val_loss: 0.0795 - val_out_caps_loss: 0.0794 - val_out_recon_loss: 0.0587 - val_out_caps_acc: 0.9000
#
# Epoch 00033: val_loss did not improve from 0.07649
# Epoch 34/50
# 393/393 [==============================] - 375s 955ms/step - loss: 0.0689 - out_caps_loss: 0.0689 - out_recon_loss: 0.0524 - out_caps_acc: 0.9055 - val_loss: 0.0779 - val_out_caps_loss: 0.0778 - val_out_recon_loss: 0.0590 - val_out_caps_acc: 0.9000
#
# Epoch 00034: val_loss did not improve from 0.07649
# Epoch 35/50
# 393/393 [==============================] - 376s 957ms/step - loss: 0.0692 - out_caps_loss: 0.0691 - out_recon_loss: 0.0526 - out_caps_acc: 0.9074 - val_loss: 0.0753 - val_out_caps_loss: 0.0753 - val_out_recon_loss: 0.0584 - val_out_caps_acc: 0.9000
#
# Epoch 00035: val_loss improved from 0.07649 to 0.07528, saving model to weights-35.h5
# Epoch 36/50
# 393/393 [==============================] - 375s 955ms/step - loss: 0.0686 - out_caps_loss: 0.0686 - out_recon_loss: 0.0525 - out_caps_acc: 0.9059 - val_loss: 0.0748 - val_out_caps_loss: 0.0748 - val_out_recon_loss: 0.0585 - val_out_caps_acc: 0.9000
#
# Epoch 00036: val_loss improved from 0.07528 to 0.07482, saving model to weights-36.h5
# Epoch 37/50
# 393/393 [==============================] - 375s 954ms/step - loss: 0.0686 - out_caps_loss: 0.0686 - out_recon_loss: 0.0525 - out_caps_acc: 0.9053 - val_loss: 0.0759 - val_out_caps_loss: 0.0758 - val_out_recon_loss: 0.0585 - val_out_caps_acc: 0.9000
#
# Epoch 00037: val_loss did not improve from 0.07482
# Epoch 38/50
# 393/393 [==============================] - 376s 957ms/step - loss: 0.0692 - out_caps_loss: 0.0692 - out_recon_loss: 0.0523 - out_caps_acc: 0.9047 - val_loss: 0.0782 - val_out_caps_loss: 0.0781 - val_out_recon_loss: 0.0586 - val_out_caps_acc: 0.9000
#
# Epoch 00038: val_loss did not improve from 0.07482
# Epoch 39/50
# 393/393 [==============================] - 375s 954ms/step - loss: 0.0680 - out_caps_loss: 0.0680 - out_recon_loss: 0.0526 - out_caps_acc: 0.9088 - val_loss: 0.0765 - val_out_caps_loss: 0.0764 - val_out_recon_loss: 0.0584 - val_out_caps_acc: 0.9000
#
# Epoch 00039: val_loss did not improve from 0.07482
# Epoch 40/50
# 393/393 [==============================] - 376s 956ms/step - loss: 0.0670 - out_caps_loss: 0.0670 - out_recon_loss: 0.0524 - out_caps_acc: 0.9093 - val_loss: 0.0781 - val_out_caps_loss: 0.0781 - val_out_recon_loss: 0.0584 - val_out_caps_acc: 0.8833
#
# Epoch 00040: val_loss did not improve from 0.07482
# Epoch 41/50
# 393/393 [==============================] - 375s 955ms/step - loss: 0.0677 - out_caps_loss: 0.0677 - out_recon_loss: 0.0522 - out_caps_acc: 0.9079 - val_loss: 0.0795 - val_out_caps_loss: 0.0795 - val_out_recon_loss: 0.0586 - val_out_caps_acc: 0.9000
#
# Epoch 00041: val_loss did not improve from 0.07482
# Epoch 42/50
# 393/393 [==============================] - 375s 955ms/step - loss: 0.0685 - out_caps_loss: 0.0684 - out_recon_loss: 0.0523 - out_caps_acc: 0.9070 - val_loss: 0.0770 - val_out_caps_loss: 0.0769 - val_out_recon_loss: 0.0586 - val_out_caps_acc: 0.9000
#
# Epoch 00042: val_loss did not improve from 0.07482
# Epoch 43/50
# 393/393 [==============================] - 376s 956ms/step - loss: 0.0666 - out_caps_loss: 0.0666 - out_recon_loss: 0.0523 - out_caps_acc: 0.9098 - val_loss: 0.0770 - val_out_caps_loss: 0.0770 - val_out_recon_loss: 0.0584 - val_out_caps_acc: 0.9000
#
# Epoch 00043: val_loss did not improve from 0.07482
# Epoch 44/50
# 393/393 [==============================] - 375s 954ms/step - loss: 0.0675 - out_caps_loss: 0.0675 - out_recon_loss: 0.0524 - out_caps_acc: 0.9093 - val_loss: 0.0793 - val_out_caps_loss: 0.0793 - val_out_recon_loss: 0.0587 - val_out_caps_acc: 0.9000
#
# Epoch 00044: val_loss did not improve from 0.07482
# Epoch 45/50
# 393/393 [==============================] - 376s 956ms/step - loss: 0.0659 - out_caps_loss: 0.0658 - out_recon_loss: 0.0523 - out_caps_acc: 0.9097 - val_loss: 0.0811 - val_out_caps_loss: 0.0811 - val_out_recon_loss: 0.0585 - val_out_caps_acc: 0.9000
#
# Epoch 00045: val_loss did not improve from 0.07482
# Epoch 46/50
# 393/393 [==============================] - 375s 955ms/step - loss: 0.0670 - out_caps_loss: 0.0670 - out_recon_loss: 0.0524 - out_caps_acc: 0.9095 - val_loss: 0.0789 - val_out_caps_loss: 0.0789 - val_out_recon_loss: 0.0585 - val_out_caps_acc: 0.9000
#
# Epoch 00046: val_loss did not improve from 0.07482
# Epoch 47/50
# 393/393 [==============================] - 375s 955ms/step - loss: 0.0660 - out_caps_loss: 0.0660 - out_recon_loss: 0.0523 - out_caps_acc: 0.9114 - val_loss: 0.0805 - val_out_caps_loss: 0.0805 - val_out_recon_loss: 0.0584 - val_out_caps_acc: 0.9000
#
# Epoch 00047: val_loss did not improve from 0.07482
# Epoch 48/50
# 393/393 [==============================] - 376s 956ms/step - loss: 0.0662 - out_caps_loss: 0.0662 - out_recon_loss: 0.0523 - out_caps_acc: 0.9115 - val_loss: 0.0796 - val_out_caps_loss: 0.0796 - val_out_recon_loss: 0.0582 - val_out_caps_acc: 0.9000
#
# Epoch 00048: val_loss did not improve from 0.07482
# Epoch 49/50
# 393/393 [==============================] - 375s 954ms/step - loss: 0.0658 - out_caps_loss: 0.0658 - out_recon_loss: 0.0523 - out_caps_acc: 0.9090 - val_loss: 0.0777 - val_out_caps_loss: 0.0777 - val_out_recon_loss: 0.0583 - val_out_caps_acc: 0.9000
#
# Epoch 00049: val_loss did not improve from 0.07482
# Epoch 50/50
# 393/393 [==============================] - 376s 956ms/step - loss: 0.0676 - out_caps_loss: 0.0675 - out_recon_loss: 0.0521 - out_caps_acc: 0.9081 - val_loss: 0.0782 - val_out_caps_loss: 0.0782 - val_out_recon_loss: 0.0583 - val_out_caps_acc: 0.9000
#
# Epoch 00050: val_loss did not improve from 0.07482
# Trained model saved to 'trained_model.h5'

# %%
def combine_images(generated_images):
    num = generated_images.shape[0]
    width = int(np.sqrt(num))
    height = int(np.ceil(float(num)/width))
    shape = generated_images.shape[1:3]
    image = np.zeros((height*shape[0], width*shape[1]),
                     dtype=generated_images.dtype)
    for index, img in enumerate(generated_images):
        i = int(index/width)
        j = index % width
        image[i*shape[0]:(i+1)*shape[0], j*shape[1]:(j+1)*shape[1]] = \
            img[:, :, 0]
    return image

def test(model, data):
    x_test, y_test = data
    y_pred, x_recon = model.predict([x_test, y_test], batch_size=100)
    print('-'*50)
    print('Test acc:', np.sum(np.argmax(y_pred, 1) == np.argmax(y_test, 1))/y_test.shape[0])

    import matplotlib.pyplot as plt
    from PIL import Image

    img = combine_images(np.concatenate([x_test[:50],x_recon[:50]]))
    image = img * 255
    Image.fromarray(image.astype(np.uint8)).save("real_and_recon.png")
    print()
    print('Reconstructed images are saved to ./real_and_recon.png')
    print('-'*50)
    plt.imshow(plt.imread("real_and_recon.png", ))
    plt.show()

# %%
test(model=model, data=(x_test[60:], y_test[60:]))
# Out:
# --------------------------------------------------
# Test acc: 0.9101449275362319
#
# Reconstructed images are saved to ./real_and_recon.png
# --------------------------------------------------

# %%
model2 = model
model2.load_weights('trained_model.h5')

# %%
test(model=model2, data=(x_test, y_test))
# Out:
# --------------------------------------------------
# Test acc: 0.9101111111111111
#
# Reconstructed images are saved to ./real_and_recon.png
# --------------------------------------------------
